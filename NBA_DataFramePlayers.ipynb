# %%
import pandas as pd

# %%
all_players = pd.read_csv('/content/drive/MyDrive/all_seasons.csv', sep = ',')

# %% [markdown]
# > # **Exploración**

# %%
# Mostrar las primeras 5 filas de la base de datos
all_players.head()
# Out:
#    Unnamed: 0       player_name team_abbreviation   age  player_height  \
# 0           0  Randy Livingston               HOU  22.0         193.04
# 1           1  Gaylon Nickerson               WAS  28.0         190.50
# 2           2      George Lynch               VAN  26.0         203.20
# 3           3    George McCloud               LAL  30.0         203.20
# 4           4      George Zidek               DEN  23.0         213.36
#
#    player_weight                college country draft_year draft_round  ...  \
# 0      94.800728        Louisiana State     USA       1996           2  ...
# 1      86.182480  Northwestern Oklahoma     USA       1994           2  ...
# 2     103.418976         North Carolina     USA       1993           1  ...
# 3     102.058200          Florida State     USA       1989           1  ...
# 4     119.748288                   UCLA     USA       1995           1  ...
#
#     pts  reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct  \
# ...

# %%
# Obtener estadísticas descriptivas de las columnas numéricas
player_describe = all_players.describe()

# %%
# Seleccionar columnas específicas
player_describe_filter = player_describe[['player_height', 'pts', 'reb', 'ast']]

# %%
player_describe_filter
# Out:
#        player_height           pts           reb           ast
# count   12844.000000  12844.000000  12844.000000  12844.000000
# mean      200.555097      8.212582      3.558486      1.824681
# std         9.111090      6.016573      2.477885      1.800840
# min       160.020000      0.000000      0.000000      0.000000
# 25%       193.040000      3.600000      1.800000      0.600000
# 50%       200.660000      6.700000      3.000000      1.200000
# 75%       208.280000     11.500000      4.700000      2.400000
# max       231.140000     36.100000     16.300000     11.700000

# %%
# Mostrar los valores únicos en cada columna
all_players.nunique()
# Out:
# Unnamed: 0           12844
# player_name           2551
# team_abbreviation       36
# age                     27
# player_height           30
# player_weight          157
# college                357
# country                 82
# draft_year              48
# draft_round              9
# draft_number            76
# gp                      85
# pts                    319
# reb                    153
# ast                    115
# net_rating             772
# oreb_pct               216
# dreb_pct               352
# usg_pct                348
# ts_pct                 563
# ast_pct                483
# season                  27
# dtype: int64

# %% [markdown]
# > # **Filtado**

# %%
# Filtrar jugadores con más de 20 puntos por partido
high_scorers = all_players[all_players['pts'] > 20]

# %%
# Seleccionar columnas específicas
high_scorers_filter = high_scorers[['player_name', 'country', 'player_height', 'pts', 'reb', 'ast']].head(10)

# %%
high_scorers_filter
# Out:
#           player_name  country  player_height   pts   reb  ast
# 7           Glen Rice      USA         203.20  26.8   4.0  2.0
# 8      Glenn Robinson      USA         200.66  21.1   6.3  3.1
# 9          Grant Hill      USA         203.20  21.4   9.0  7.3
# 18    Hakeem Olajuwon  Nigeria         213.36  23.2   9.2  3.0
# 22        Gary Payton      USA         193.04  21.8   4.6  7.1
# 51   Jerry Stackhouse      USA         198.12  20.7   4.2  3.1
# 104      Chris Webber      USA         208.28  20.1  10.3  4.6
# 144  Damon Stoudamire      USA         177.80  20.2   4.1  8.8
# 200    Scottie Pippen      USA         200.66  20.2   6.5  5.7
# 206  Shaquille O'Neal      USA         215.90  26.2  12.5  3.1

# %%
# Filtrar jugadores de una temporada específica y un equipo específico
specific_season_team = all_players[(all_players['season'] == '2022-23') & (all_players['team_abbreviation'] == 'LAL')]

# %%
# Seleccionar columnas específicas
specific_season_team_filter = specific_season_team[['player_name', 'country', 'team_abbreviation', 'season', 'player_height', 'pts', 'reb', 'ast']].head(10)

# %%
specific_season_team_filter
# Out:
#               player_name      country team_abbreviation   season  \
# 12331       Rui Hachimura        Japan               LAL  2022-23
# 12356            Mo Bamba          USA               LAL  2022-23
# 12400      Troy Brown Jr.          USA               LAL  2022-23
# 12422      Wenyen Gabriel  South Sudan               LAL  2022-23
# 12433      Sterling Brown          USA               LAL  2022-23
# 12440  Shaquille Harrison          USA               LAL  2022-23
# 12446   Scotty Pippen Jr.          USA               LAL  2022-23
# 12491     Dennis Schroder      Germany               LAL  2022-23
# 12505          Davon Reed          USA               LAL  2022-23
# 12567       Austin Reaves          USA               LAL  2022-23
#
#        player_height   pts  reb  ast
# 12331         203.20  11.2  4.5  0.9
# 12356         213.36   6.6  4.6  0.9
# 12400         200.66   7.1  4.1  1.3
# 12422         205.74   5.5  4.2  0.5
# 12433         195.58   0.0  2.0  0.5
# ...

# %%
# Filtrar jugadores solo de un país específico (por ejemplo, USA)
Nigeria_players = all_players[all_players['country'] == 'Nigeria']

# %%
# Seleccionar columnas específicas
Nigeria_players_filter = Nigeria_players[['player_name', 'country', 'team_abbreviation', 'season', 'pts', 'reb', 'ast']].head(10)

# %%
Nigeria_players_filter
# Out:
#              player_name  country team_abbreviation   season   pts  reb  ast
# 18       Hakeem Olajuwon  Nigeria               HOU  1996-97  23.2  9.2  3.0
# 783      Hakeem Olajuwon  Nigeria               HOU  1997-98  16.4  9.8  3.0
# 937      Hakeem Olajuwon  Nigeria               HOU  1998-99  18.9  9.6  1.8
# 1266  Michael Olowokandi  Nigeria               LAC  1998-99   8.9  7.9  0.6
# 1323  Michael Olowokandi  Nigeria               LAC  1999-00   9.8  8.2  0.5
# 1342       Obinna Ekezie  Nigeria               VAN  1999-00   3.2  2.4  0.2
# 1701     Hakeem Olajuwon  Nigeria               HOU  1999-00  10.3  6.2  1.4
# 1814     Hakeem Olajuwon  Nigeria               HOU  2000-01  11.9  7.4  1.2
# 1837  Michael Olowokandi  Nigeria               LAC  2000-01   8.5  6.4  0.6
# 1856     Olumide Oyedeji  Nigeria               SEA  2000-01   1.5  2.2  0.1

# %% [markdown]
# > # **Limpieza**

# %%
# Eliminar columnas que no son relevantes para el análisis
all_players_cleaned = all_players.drop(['college', 'draft_year', 'draft_round'], axis=1)

# %%
all_players_cleaned
# Out:
#        Unnamed: 0       player_name team_abbreviation   age  player_height  \
# 0               0  Randy Livingston               HOU  22.0         193.04
# 1               1  Gaylon Nickerson               WAS  28.0         190.50
# 2               2      George Lynch               VAN  26.0         203.20
# 3               3    George McCloud               LAL  30.0         203.20
# 4               4      George Zidek               DEN  23.0         213.36
# ...           ...               ...               ...   ...            ...
# 12839       12839       Joel Embiid               PHI  29.0         213.36
# 12840       12840   John Butler Jr.               POR  20.0         213.36
# 12841       12841      John Collins               ATL  25.0         205.74
# 12842       12842      Jericho Sims               NYK  24.0         208.28
# 12843       12843    JaMychal Green               GSW  33.0         205.74
#
# ...

# %%
# Verificar duplicados en el DataFrame 'all_players' y sumarlos
all_players_duplicates = all_players.duplicated().sum()

# %%
all_players_duplicates
# Out:
# 0

# %%
# Eliminar filas duplicadas
all_players_no_duplicates = all_players.drop_duplicates()

# %%
# Contar el número de filas duplicadas después de la eliminación
num_duplicates_after = all_players_no_duplicates.duplicated().sum()

# %%
num_duplicates_after
# Out:
# 0

# %%
# Identificar y tratar valores faltantes en la columna 'college'
missing_college_count = all_players['college'].isnull().sum()

# Imprimir la cantidad de valores faltantes antes del tratamiento
print("Cantidad de valores faltantes en la columna 'college' antes del tratamiento:", missing_college_count)

# Rellenar los valores faltantes con un valor predeterminado
default_college_value = "No College"
all_players['college'].fillna(default_college_value, inplace=True)

# Imprimir la cantidad de valores faltantes después del tratamiento
missing_college_count_after = all_players['college'].isnull().sum()
# Out:
# Cantidad de valores faltantes en la columna 'college' antes del tratamiento: 0

# %%
missing_college_count_after
# Out:
# 0

# %% [markdown]
# > # **Análisis**

# %%
# Identificar jugadores destacados
# Selecciona filas donde puntos ('pts'), rebotes ('reb') y asistencias ('ast') son mayores que el promedio respectivo
standout_players = all_players.loc[(all_players['pts'] > all_players['pts'].mean()) & (all_players['reb'] > all_players['reb'].mean()) & (all_players['ast'] > all_players['ast'].mean())].tail(10)

# %%
# Seleccionar columnas específicas
standout_players_filter = standout_players[['player_name', 'age', 'team_abbreviation', 'pts', 'reb', 'ast', 'season']]

# %%
# Imprimimos los datos seleccionados y especificamos el filtro descendentemente
standout_players_filter.sort_values(by='pts', ascending=False)
# Out:
#            player_name   age team_abbreviation   pts   reb  ast   season
# 12839      Joel Embiid  29.0               PHI  33.1  10.2  4.2  2022-23
# 12825     Jayson Tatum  25.0               BOS  30.1   8.8  4.6  2022-23
# 12822     Jaylen Brown  26.0               BOS  26.6   6.9  3.5  2022-23
# 12834     Jimmy Butler  33.0               MIA  22.9   5.9  5.3  2022-23
# 12802  Jordan Clarkson  31.0               UTA  20.8   4.0  4.4  2022-23
# 12829     Jerami Grant  29.0               POR  20.5   4.5  2.4  2022-23
# 12811      Josh Giddey  20.0               OKC  16.6   7.9  6.2  2022-23
# 12794     Jakob Poeltl  27.0               TOR  12.5   9.1  2.7  2022-23
# 12832    Jeremy Sochan  20.0               SAS  11.0   5.3  2.5  2022-23
# 12813        Josh Hart  28.0               NYK   9.8   7.8  3.8  2022-23

# %%
# Identificar el jugador más antiguo y más joven
oldest_player = all_players.loc[all_players['age'].idxmax()]
youngest_player = all_players.loc[all_players['age'].idxmin()]

# Mostrar la información de los jugadores
print("Jugador más antiguo:")
print(oldest_player[['player_name', 'age', 'team_abbreviation', 'pts', 'reb', 'ast', 'season']])
print("\nJugador más joven:")
print(youngest_player[['player_name', 'age', 'team_abbreviation', 'pts', 'reb', 'ast', 'season']])
# Out:
# Jugador más antiguo:
# player_name          Kevin Willis
# age                          44.0
# team_abbreviation             DAL
# pts                           2.4
# reb                           1.6
# ast                           0.2
# season                    2006-07
# Name: 4844, dtype: object
#
# Jugador más joven:
# player_name          Jermaine O'Neal
# age                             18.0
# team_abbreviation                POR
# pts                              4.1
# reb                              2.8
# ast                              0.2
# season                       1996-97
# Name: 72, dtype: object

# %% [markdown]
# > # **Visualización**

# %%
import matplotlib.pyplot as plt

# Crear un gráfico de líneas para la distribución de edades
plt.plot(all_players['age'].value_counts().sort_index(), marker='o', linestyle='-', color='black')
plt.title('Distribución de Edades de Jugadores')
plt.xlabel('Edad')
plt.ylabel('Cantidad')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Contar la frecuencia de cada altura y ordenar por índice
height_all_players = all_players['player_height'].value_counts().sort_index()

# Crear un gráfico de líneas para la distribución de alturas
plt.plot(height_all_players, marker='o', linestyle='-', color='black')
plt.title('Distribución de Alturas de Jugadores')
plt.xlabel('Altura')
plt.ylabel('Cantidad')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Redondear la edad a números enteros
all_players['age_rounded'] = all_players['age'].astype(int)

# Agrupar por altura y contar la frecuencia de edades
height_age_counts = all_players.groupby('player_height')['age_rounded'].value_counts().unstack().fillna(0)

# Crear un gráfico de barras apiladas
height_age_counts.plot(kind='bar', stacked=True, colormap='viridis')

plt.title('Distribución de Edades por Altura de Jugadores')
plt.xlabel('Altura')
plt.ylabel('Frecuencia')
plt.legend(title='Edad', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
